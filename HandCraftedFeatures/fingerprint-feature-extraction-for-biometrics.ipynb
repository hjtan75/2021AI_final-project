# %% [markdown]
# # Fingerprint Feature Extraction

# %% [markdown]
# ### Introduction:
#
# Fingerprint biometrics involve: Image Acquisition, Image Enhancing, Feature extraction and matching with template. Since the dataset has unique fingerprints I will implement feature extraction and different techniques for enhancing images such as Edge detection, adaptive thresholding. Feature extraction constitutes of Ridge detection (level 1 feature) and Minutiae extraction (level 3 feature) to generate a template after whicha query image is matched using the metric ROC AUC curve.

# %% [markdown]
# ### Dependencies and Data

# %%
import numpy as np
import glob
import random
import imageio
import PIL, cv2
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from skimage.morphology import convex_hull_image, erosion
from skimage.morphology import square
import matplotlib.image as mpimg
import skimage
import math
from scipy.ndimage.filters import convolve
from PIL import Image,ImageFilter
from skimage.feature import hessian_matrix, hessian_matrix_eigvals
import os

# %%
# KAGGLE FINGERPRINT DATA

DATA_DIR = "../SOCOFing/Real/"
list_dirs = list(glob.glob(DATA_DIR+"*.BMP"))
num_images = len(list_dirs)

# %%
num_images
# Out:
# 6000

# %% [markdown]
# ### Termination and Bifurcation detection and Minutiae Extraction
#
# The given code extracts features like Termination, Bifurcation and Minutiae from finger prints, the output is shown below the code:

# %%
def getTerminationBifurcation(img, mask):
    img = img == 255;
    (rows, cols) = img.shape;
    minutiaeTerm = np.zeros(img.shape);
    minutiaeBif = np.zeros(img.shape);
    
    for i in range(1,rows-1):
        for j in range(1,cols-1):
            if(img[i][j] == 1):
                block = img[i-1:i+2,j-1:j+2];
                block_val = np.sum(block);
                if(block_val == 2):
                    minutiaeTerm[i,j] = 1;
                elif(block_val == 4):
                    minutiaeBif[i,j] = 1;
    
    mask = convex_hull_image(mask>0)
    mask = erosion(mask, square(5))         
    minutiaeTerm = np.uint8(mask)*minutiaeTerm
    return(minutiaeTerm, minutiaeBif)

# %%
class MinutiaeFeature(object):
    def __init__(self, locX, locY, Orientation, Type):
        self.locX = locX;
        self.locY = locY;
        self.Orientation = Orientation;
        self.Type = Type;

def computeAngle(block, minutiaeType):
    angle = 0
    (blkRows, blkCols) = np.shape(block);
    CenterX, CenterY = (blkRows-1)/2, (blkCols-1)/2
    if(minutiaeType.lower() == 'termination'):
        sumVal = 0;
        for i in range(blkRows):
            for j in range(blkCols):
                if((i == 0 or i == blkRows-1 or j == 0 or j == blkCols-1) and block[i][j] != 0):
                    angle = -math.degrees(math.atan2(i-CenterY, j-CenterX))
                    sumVal += 1
                    if(sumVal > 1):
                        angle = float('nan');
        return(angle)
    elif(minutiaeType.lower() == 'bifurcation'):
        (blkRows, blkCols) = np.shape(block);
        CenterX, CenterY = (blkRows - 1) / 2, (blkCols - 1) / 2
        angle = []
        sumVal = 0;
        for i in range(blkRows):
            for j in range(blkCols):
                if ((i == 0 or i == blkRows - 1 or j == 0 or j == blkCols - 1) and block[i][j] != 0):
                    angle.append(-math.degrees(math.atan2(i - CenterY, j - CenterX)))
                    sumVal += 1
        if(sumVal != 3):
            angle = float('nan')
        return(angle)


def extractMinutiaeFeatures(skel, minutiaeTerm, minutiaeBif):
    FeaturesTerm = []

    minutiaeTerm = skimage.measure.label(minutiaeTerm, connectivity=2);
    RP = skimage.measure.regionprops(minutiaeTerm)
    
    WindowSize = 2          
    FeaturesTerm = []
    for i in RP:
        (row, col) = np.int16(np.round(i['Centroid']))
        block = skel[row-WindowSize:row+WindowSize+1, col-WindowSize:col+WindowSize+1]
        angle = computeAngle(block, 'Termination')
        FeaturesTerm.append(MinutiaeFeature(row, col, angle, 'Termination'))

    FeaturesBif = []
    minutiaeBif = skimage.measure.label(minutiaeBif, connectivity=2);
    RP = skimage.measure.regionprops(minutiaeBif)
    WindowSize = 1 
    for i in RP:
        (row, col) = np.int16(np.round(i['Centroid']))
        block = skel[row-WindowSize:row+WindowSize+1, col-WindowSize:col+WindowSize+1]
        angle = computeAngle(block, 'Bifurcation')
        FeaturesBif.append(MinutiaeFeature(row, col, angle, 'Bifurcation'))
    return(FeaturesTerm, FeaturesBif)

def ShowResults(skel, TermLabel, BifLabel):
    minutiaeBif = TermLabel * 0;
    minutiaeTerm = BifLabel * 0;

    (rows, cols) = skel.shape
    DispImg = np.zeros((rows, cols, 3), np.uint8)
    DispImg[:, :, 0] = skel;
    DispImg[:, :, 1] = skel;
    DispImg[:, :, 2] = skel;

    RP = skimage.measure.regionprops(BifLabel)
    for idx, i in enumerate(RP):
        (row, col) = np.int16(np.round(i['Centroid']))
        minutiaeBif[row, col] = 1;
        (rr, cc) = skimage.draw.circle_perimeter(row, col, 1);
        skimage.draw.set_color(DispImg, (rr, cc), (255, 0, 0));

    RP = skimage.measure.regionprops(TermLabel)
    for idx, i in enumerate(RP):
        (row, col) = np.int16(np.round(i['Centroid']))
        minutiaeTerm[row, col] = 1;
        (rr, cc) = skimage.draw.circle_perimeter(row, col, 1);
        skimage.draw.set_color(DispImg, (rr, cc), (0, 0, 255));
        
    plt.figure(figsize=(6,6))
    plt.title("Minutiae extraction results")
    plt.imshow(DispImg)

# %%
def extract_label(img_path,train = True):
    filename, _ = os.path.splitext(os.path.basename(img_path))

    subject_id, etc = filename.split('__')
    noise = ""
    
    # train data contain what type of noise in the end, ex. 100__M_Left_thumb_finger_Obl.BMP
    if train:
        gender, lr, finger, _, noise = etc.split('_')
    else:
        gender, lr, finger, _ = etc.split('_')
  
    gender = 0 if gender == 'M' else 1
    lr = 0 if lr == 'Left' else 1

    # We want to return which finger it is
    if finger == 'thumb':
        finger = 0
    elif finger == 'index':
        finger = 1
    elif finger == 'middle':
        finger = 2
    elif finger == 'ring':
        finger = 3
    elif finger == 'little':
        finger = 4
    
    return subject_id, noise

# %%
# save all the feature from all the finger 
# the database store all the information of the finger print location
# bif_location store the x,y of the feature
# fingerprint_database: axis: number of finger print, axis2: bif_locations, term_locations
# TermLabel: return the position of termination
# BifLabel: return the position of Bifurcation

term_database = []
bif_database = []
id_database = []

index = 1
for file in list_dirs:
    if index%1000 == 0:
        print("Testing image number:", index)
    image = cv2.imread(file, 0)
    image = image[0:94,0:94]
    ret, th = cv2.threshold(image,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU) 
    th = th/255
    skeleton = skimage.morphology.skeletonize(th)
    skeleton = np.uint8(skeleton)*255
    mask = image*255

    (minutiaeTerm, minutiaeBif) = getTerminationBifurcation(skeleton, mask)
    FeaturesTerm, FeaturesBif = extractMinutiaeFeatures(skeleton, minutiaeTerm, minutiaeBif)
    BifLabel = skimage.measure.label(minutiaeBif, connectivity=1) >= 1
    BifLabel = BifLabel.astype(int)
    TermLabel = skimage.measure.label(minutiaeTerm, connectivity=1) >= 1
    TermLabel = TermLabel.astype(int)
    
    id_, noise = extract_label(file,train = False)
    id_database.append(id_)
    bif_database.append(BifLabel)
    term_database.append(TermLabel)
    index += 1
# Out:
# Testing image number: 1000
# Testing image number: 2000
# Testing image number: 3000
# Testing image number: 4000
# Testing image number: 5000
# Testing image number: 6000

# %%
id_database[0]
# Out:
# '100'

# %%
def noisy(noise_typ,image):
    if noise_typ == "gauss":
        row,col= image.shape
        mean = 0
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col))
        gauss = gauss.reshape(row,col)
        noisy = image + gauss
        return noisy

    elif noise_typ == "s&p":
        row,col = image.shape
        s_vs_p = 0.5
        amount = 0.004
        out = np.copy(image)
        # Salt mode
        num_salt = np.ceil(amount * image.size * s_vs_p)
        coords = [np.random.randint(0, i - 1, int(num_salt))
              for i in image.shape]
        out[coords] = 1

        # Pepper mode
        num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
        coords = [np.random.randint(0, i - 1, int(num_pepper))
              for i in image.shape]
        out[coords] = 0
        return out
    elif noise_typ == "poisson":
        vals = len(np.unique(image))
        vals = 2 ** np.ceil(np.log2(vals))
        noisy = np.random.poisson(image * vals) / float(vals)
        return noisy
    elif noise_typ =="speckle":
        row,col = image.shape
        gauss = np.random.randn(row,col)
        gauss = gauss.reshape(row,col)        
        noisy = image + image * gauss
        return noisy

# %%
# testing image
test_DATA_DIR = "../SOCOFing/Real/"
num_true = 0
num_image_tested = 0
b_d = np.array(bif_database)
t_d = np.array(term_database)

test_list_dirs = list(glob.glob(test_DATA_DIR+"*.BMP"))
test_num_images = len(test_list_dirs)

print(test_num_images)
while num_image_tested <= 100:
    idx = random.randint(0, test_num_images-1)
    print(idx)
    file = test_list_dirs[idx]
    test_id, n = extract_label(file, False)
#     if n != "Obl":
#         continue
        
    print("Testing image number:", num_image_tested)
    print("Preprocessing image")
        
    test_image = cv2.imread(file, 0)
    test_image = test_image[0:94,0:94]
    
    noisy_image = noisy("poisson", test_image)
    noisy_image = noisy_image.astype('uint8')
    test_ret, test_th = cv2.threshold(noisy_image,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU) 
    test_th = test_th/255
    test_skeleton = skimage.morphology.skeletonize(test_th)
    test_skeleton = np.uint8(test_skeleton)*255
    test_mask = test_image*255

    (minutiaeTerm, minutiaeBif) = getTerminationBifurcation(test_skeleton, test_mask)
    FeaturesTerm, FeaturesBif = extractMinutiaeFeatures(skeleton, minutiaeTerm, minutiaeBif)
    test_BifLabel = skimage.measure.label(minutiaeBif, connectivity=1)  >= 1
    test_BifLabel = test_BifLabel.astype(int)
    test_TermLabel = skimage.measure.label(minutiaeTerm, connectivity=1)  >= 1
    test_TermLabel = test_TermLabel.astype(int)

    
    print("Calculating MSE")
    # calcalculate mse
    error = []
    for i in range(len(b_d)): 
#         if i%100 == 0:
#             print(i)
        mse = (np.square(b_d[i] - test_BifLabel)).mean(axis=0).mean(axis=0)
        mse += (np.square(t_d[i] - test_TermLabel)).mean(axis=0).mean(axis=0)
        error.append(mse)
    
    error = np.array(error)
    print("Real:", id_database[error.argmin()], "Predicted:", test_id)
    if id_database[error.argmin()] == test_id:
        num_true += 1
        
    num_image_tested += 1
    
print("Accuracy:", num_true/num_image_tested*100)
# Out:
# 6000
# 3290
# Testing image number: 0
# Preprocessing image
# Calculating MSE
# Real: 226 Predicted: 398
# 833
# Testing image number: 1
# Preprocessing image
# Calculating MSE
# Real: 176 Predicted: 176
# 4404
# Testing image number: 2
# Preprocessing image
# Calculating MSE
# Real: 498 Predicted: 498
# 1689
# Testing image number: 3
# Preprocessing image
# Calculating MSE
# Real: 252 Predicted: 252
# 2106
# Testing image number: 4
# Preprocessing image
# Calculating MSE
# Real: 290 Predicted: 290
# 2334
# Testing image number: 5
# Preprocessing image
# Calculating MSE
# Real: 310 Predicted: 310
# 4706
# Testing image number: 6
# Preprocessing image
# Calculating MSE
# Real: 524 Predicted: 524
# 692
# Testing image number: 7
# Preprocessing image
# Calculating MSE
# Real: 163 Predicted: 163
# 1807
# Testing image number: 8
# Preprocessing image
# Calculating MSE
# Real: 263 Predicted: 263
# 2399
# Testing image number: 9
# Preprocessing image
# Calculating MSE
# Real: 316 Predicted: 316
# 1182
# Testing image number: 10
# Preprocessing image
# Calculating MSE
# Real: 207 Predicted: 207
# 5784
# Testing image number: 11
# Preprocessing image
# Calculating MSE
# Real: 80 Predicted: 80
# 5148
# Testing image number: 12
# Preprocessing image
# Calculating MSE
# Real: 564 Predicted: 564
# 1446
# Testing image number: 13
# Preprocessing image
# Calculating MSE
# Real: 230 Predicted: 230
# 505
# Testing image number: 14
# Preprocessing image
# Calculating MSE
# Real: 146 Predicted: 146
# 2063
# Testing image number: 15
# Preprocessing image
# Calculating MSE
# Real: 287 Predicted: 287
# 2195
# Testing image number: 16
# Preprocessing image
# Calculating MSE
# Real: 299 Predicted: 299
# 4375
# Testing image number: 17
# Preprocessing image
# Calculating MSE
# Real: 495 Predicted: 495
# 361
# Testing image number: 18
# Preprocessing image
# Calculating MSE
# Real: 133 Predicted: 133
# 5063
# Testing image number: 19
# Preprocessing image
# Calculating MSE
# Real: 557 Predicted: 557
# 442
# Testing image number: 20
# Preprocessing image
# Calculating MSE
# Real: 140 Predicted: 140
# 3452
# Testing image number: 21
# Preprocessing image
# Calculating MSE
# Real: 411 Predicted: 411
# 3954
# Testing image number: 22
# Preprocessing image
# Calculating MSE
# Real: 457 Predicted: 457
# 4717
# Testing image number: 23
# Preprocessing image
# Calculating MSE
# Real: 525 Predicted: 525
# 4555
# Testing image number: 24
# Preprocessing image
# Calculating MSE
# Real: 510 Predicted: 510
# 3778
# Testing image number: 25
# Preprocessing image
# Calculating MSE
# Real: 440 Predicted: 440
# 5236
# Testing image number: 26
# Preprocessing image
# Calculating MSE
# Real: 226 Predicted: 572
# 4112
# Testing image number: 27
# Preprocessing image
# Calculating MSE
# Real: 471 Predicted: 471
# 1796
# Testing image number: 28
# Preprocessing image
# Calculating MSE
# Real: 262 Predicted: 262
# 5470
# Testing image number: 29
# Preprocessing image
# Calculating MSE
# Real: 594 Predicted: 594
# 1991
# Testing image number: 30
# Preprocessing image
# Calculating MSE
# Real: 280 Predicted: 280
# 3604
# Testing image number: 31
# Preprocessing image
# Calculating MSE
# Real: 226 Predicted: 425
# 4615
# Testing image number: 32
# Preprocessing image
# Calculating MSE
# Real: 516 Predicted: 516
# 4731
# Testing image number: 33
# Preprocessing image
# Calculating MSE
# Real: 527 Predicted: 527
# 4761
# Testing image number: 34
# Preprocessing image
# Calculating MSE
# Real: 52 Predicted: 52
# 498
# Testing image number: 35
# Preprocessing image
# Calculating MSE
# Real: 145 Predicted: 145
# 2887
# Testing image number: 36
# Preprocessing image
# Calculating MSE
# Real: 360 Predicted: 360
# 3783
# Testing image number: 37
# Preprocessing image
# Calculating MSE
# Real: 441 Predicted: 441
# 3911
# Testing image number: 38
# Preprocessing image
# Calculating MSE
# Real: 453 Predicted: 453
# 5974
# Testing image number: 39
# Preprocessing image
# Calculating MSE
# Real: 98 Predicted: 98
# 5552
# Testing image number: 40
# Preprocessing image
# Calculating MSE
# Real: 600 Predicted: 600
# 2794
# Testing image number: 41
# Preprocessing image
# Calculating MSE
# Real: 352 Predicted: 352
# 3821
# Testing image number: 42
# Preprocessing image
# Calculating MSE
# Real: 445 Predicted: 445
# 2602
# Testing image number: 43
# Preprocessing image
# Calculating MSE
# Real: 335 Predicted: 335
# 2721
# Testing image number: 44
# Preprocessing image
# Calculating MSE
# Real: 346 Predicted: 346
# 4191
# Testing image number: 45
# Preprocessing image
# Calculating MSE
# Real: 226 Predicted: 479
# 3625
# Testing image number: 46
# Preprocessing image
# Calculating MSE
# Real: 427 Predicted: 427
# 1134
# Testing image number: 47
# Preprocessing image
# Calculating MSE
# Real: 202 Predicted: 202
# 1702
# Testing image number: 48
# Preprocessing image
# Calculating MSE
# Real: 254 Predicted: 254
# 2438
# Testing image number: 49
# Preprocessing image
# Calculating MSE
# Real: 31 Predicted: 31
# 3730
# Testing image number: 50
# Preprocessing image
# Calculating MSE
# Real: 437 Predicted: 437
# 3742
# Testing image number: 51
# Preprocessing image
# Calculating MSE
# Real: 438 Predicted: 438
# 371
# Testing image number: 52
# Preprocessing image
# Calculating MSE
# Real: 134 Predicted: 134
# 1210
# Testing image number: 53
# Preprocessing image
# Calculating MSE
# Real: 20 Predicted: 20
# 5425
# Testing image number: 54
# Preprocessing image
# Calculating MSE
# Real: 58 Predicted: 58
# 4480
# Testing image number: 55
# Preprocessing image
# Calculating MSE
# Real: 504 Predicted: 504
# 167
# Testing image number: 56
# Preprocessing image
# Calculating MSE
# Real: 115 Predicted: 115
# 2754
# Testing image number: 57
# Preprocessing image
# Calculating MSE
# Real: 349 Predicted: 349
# 3737
# Testing image number: 58
# Preprocessing image
# Calculating MSE
# Real: 437 Predicted: 437
# 1232
# Testing image number: 59
# Preprocessing image
# Calculating MSE
# Real: 211 Predicted: 211
# 3870
# Testing image number: 60
# Preprocessing image
# Calculating MSE
# Real: 44 Predicted: 44
# 4274
# Testing image number: 61
# Preprocessing image
# Calculating MSE
# Real: 486 Predicted: 486
# 3554
# Testing image number: 62
# Preprocessing image
# Calculating MSE
# Real: 420 Predicted: 420
# 5684
# Testing image number: 63
# Preprocessing image
# Calculating MSE
# Real: 71 Predicted: 71
# 4455
# Testing image number: 64
# Preprocessing image
# Calculating MSE
# Real: 501 Predicted: 501
# 2809
# Testing image number: 65
# Preprocessing image
# Calculating MSE
# Real: 353 Predicted: 353
# 2994
# Testing image number: 66
# Preprocessing image
# Calculating MSE
# Real: 370 Predicted: 370
# 1952
# Testing image number: 67
# Preprocessing image
# Calculating MSE
# Real: 277 Predicted: 277
# 1244
# Testing image number: 68
# Preprocessing image
# Calculating MSE
# Real: 212 Predicted: 212
# 4831
# Testing image number: 69
# Preprocessing image
# Calculating MSE
# Real: 536 Predicted: 536
# 4981
# Testing image number: 70
# Preprocessing image
# Calculating MSE
# Real: 54 Predicted: 54
# 130
# Testing image number: 71
# Preprocessing image
# Calculating MSE
# Real: 112 Predicted: 112
# 3075
# Testing image number: 72
# Preprocessing image
# Calculating MSE
# Real: 378 Predicted: 378
# 5661
# Testing image number: 73
# Preprocessing image
# Calculating MSE
# Real: 226 Predicted: 6
# 5188
# Testing image number: 74
# Preprocessing image
# Calculating MSE
# Real: 568 Predicted: 568
# 2455
# Testing image number: 75
# Preprocessing image
# Calculating MSE
# Real: 321 Predicted: 321
# 0
# Testing image number: 76
# Preprocessing image
# Calculating MSE
# Real: 100 Predicted: 100
# 2367
# Testing image number: 77
# Preprocessing image
# Calculating MSE
# Real: 313 Predicted: 313
# 741
# Testing image number: 78
# Preprocessing image
# Calculating MSE
# Real: 168 Predicted: 168
# 2120
# Testing image number: 79
# Preprocessing image
# Calculating MSE
# Real: 292 Predicted: 292
# 3780
# Testing image number: 80
# Preprocessing image
# Calculating MSE
# Real: 441 Predicted: 441
# 3286
# Testing image number: 81
# Preprocessing image
# Calculating MSE
# Real: 397 Predicted: 397
# 1984
# Testing image number: 82
# Preprocessing image
# Calculating MSE
# Real: 27 Predicted: 27
# 4629
# Testing image number: 83
# Preprocessing image
# Calculating MSE
# Real: 517 Predicted: 517
# 2368
# Testing image number: 84
# Preprocessing image
# Calculating MSE
# Real: 313 Predicted: 313
# 2033
# Testing image number: 85
# Preprocessing image
# Calculating MSE
# Real: 226 Predicted: 284
# 1543
# Testing image number: 86
# Preprocessing image
# Calculating MSE
# Real: 23 Predicted: 23
# 4065
# Testing image number: 87
# Preprocessing image
# Calculating MSE
# Real: 467 Predicted: 467
# 5714
# Testing image number: 88
# Preprocessing image
# Calculating MSE
# Real: 74 Predicted: 74
# 44
# Testing image number: 89
# Preprocessing image
# Calculating MSE
# Real: 104 Predicted: 104
# 4227
# Testing image number: 90
# Preprocessing image
# Calculating MSE
# Real: 481 Predicted: 481
# 5342
# Testing image number: 91
# Preprocessing image
# Calculating MSE
# Real: 582 Predicted: 582
# 5956
# Testing image number: 92
# Preprocessing image
# Calculating MSE
# Real: 96 Predicted: 96
# 3570
# Testing image number: 93
# Preprocessing image
# Calculating MSE
# Real: 422 Predicted: 422
# 1091
# Testing image number: 94
# Preprocessing image
# Calculating MSE
# Real: 19 Predicted: 19
# 3770
# Testing image number: 95
# Preprocessing image
# Calculating MSE
# Real: 440 Predicted: 440
# 4667
# Testing image number: 96
# Preprocessing image
# Calculating MSE
# Real: 520 Predicted: 520
# 4572
# Testing image number: 97
# Preprocessing image
# Calculating MSE
# Real: 512 Predicted: 512
# 4636
# Testing image number: 98
# Preprocessing image
# Calculating MSE
# Real: 518 Predicted: 518
# 1059
# Testing image number: 99
# Preprocessing image
# Calculating MSE
# Real: 196 Predicted: 196
# 5023
# Testing image number: 100
# Preprocessing image
# Calculating MSE
# Real: 553 Predicted: 553
# Accuracy: 94.05940594059405

# %%
len(bif_database)
# Out:
# 6000

# %%
b_d = np.array(bif_database)
error = []

for finger in b_d:
    mse = (np.square(finger - test_BifLabel)).mean(axis=0).mean(axis=0)
    error.append(mse)
    
print(error[0:50])
error = np.array(error)
print("Predicted Id:", id_database[error.argmin()], "Real Id: ", test_id, "Error:", mse)
# Out:
# [2138.4188546853775, 3032.7235174287002, 2121.3253734721593, 2787.240493435944, 2231.780556813037, 2322.9550701674966, 2123.5546627433228, 2545.0889542779537, 2123.5508148483473, 2682.6616115889547, 3257.9843820733367, 3035.8037573562706, 2536.54889090086, 2128.1412403802624, 8954.983703033045, 2220.500226346763, 2203.3879583521957, 2138.6698732458126, 2140.6461068356716, 2209.913761883205, 2247.9148936170213, 3454.579447713898, 2251.869058397465, 2623.661045722046, 2234.9483929379808, 2229.7858759619735, 2373.56631960163, 2152.002716161159, 2282.2437754640105, 2256.0941602535086, 2697.913082842915, 5345.024219103667, 2665.9367360796737, 2161.9968311453144, 2465.946808510638, 3206.5347442281577, 2524.882752376641, 2157.337030330466, 2163.195224083295, 2424.6140787686736, 6566.993322770483, 2129.6181530104122, 4094.2149162516976, 3047.6708918062473, 2141.711407876867, 2149.2133318243546, 2129.399049343594, 2525.9061792666366, 2428.7556586690807, 2312.13614757809]
# Predicted Id: 170 Real Id:  170 Error: 2501.1161158895425

# %%
for ids in id_database:
    print(ids)
# Out:
# 171
# 463
# 470
# 367
# 446
# 349
# 127
# 277
# 308
# 334
# 20
# 26
# 86
# 431
# 434
# 142
# 72
# 417
# 127
# 552
# 589
# 364
# 149
# 342
# 180
# 575
# 444
# 183
# 36
# 232
# 400
# 155
# 240
# 556
# 278
# 303
# 252
# 23
# 315
# 501
# 378
# 50
# 244
# 318
# 351
# 202
# 218
# 386
# 177
# 136
# 169
# 99
# 332
# 110
# 261
# 55
# 168
# 326
# 4
# 259
# 534
# 531
# 83
# 88
# 445
# 330
# 186
# 425
# 82
# 335
# 130
# 447
# 141
# 9
# 458
# 1
# 483
# 528
# 401
# 327
# 452
# 374
# 20
# 534
# 284
# 590
# 324
# 517
# 258
# 535
# 529
# 314
# 229
# 203
# 170
# 491
# 575
# 85
# 263
# 327
# 11
# 90
# 582
# 195
# 358
# 128
# 435
# 374
# 259
# 304
# 382
# 47
# 149
# 320
# 293
# 373
# 361
# 10
# 207
# 555
# 462
# 75
# 216
# 353
# 130
# 103
# 397
# 295
# 38
# 281
# 441
# 141
# 320
# 42
# 303
# 585
# 461
# 500
# 458
# 261
# 234
# 29
# 413
# 449
# 163
# 31
# 489
# 327
# 125
# 399
# 510
# 512
# 343
# 202
# 525
# 482
# 413
# 301
# 34
# 387
# 129
# 149
# 533
# 573
# 177
# 132
# 114
# 523
# 77
# 424
# 397
# 152
# 336
# 458
# 97
# 452
# 575
# 541
# 115
# 121
# 514
# 540
# 250
# 189
# 159
# 400
# 9
# 249
# 212
# 119
# 412
# 536
# 407
# 528
# 229
# 500
# 338
# 363
# 345
# 432
# 575
# 230
# 452
# 94
# 471
# 354
# 163
# 172
# 64
# 203
# 379
# 368
# 112
# 201
# 89
# 51
# 568
# 186
# 413
# 552
# 308
# 300
# 56
# 95
# 68
# 32
# 83
# 487
# 247
# 53
# 52
# 412
# 329
# 14
# 578
# 299
# 567
# 471
# 347
# 81
# 423
# 259
# 87
# 280
# 356
# 268
# 246
# 415
# 144
# 82
# 417
# 84
# 531
# 514
# 295
# 428
# 87
# 351
# 487
# 418
# 67
# 128
# 506
# 498
# 137
# 209
# 150
# 206
# 86
# 190
# 517
# 175
# 393
# 279
# 11
# 273
# 597
# 419
# 535
# 214
# 595
# 584
# 207
# 206
# 12
# 65
# 83
# 188
# 440
# 582
# 42
# 243
# 496
# 339
# 357
# 243
# 199
# 340
# 540
# 586
# 467
# 56
# 59
# 211
# 3
# 238
# 239
# 72
# 223
# 564
# 410
# 366
# 144
# 123
# 292
# 493
# 8
# 92
# 211
# 163
# 107
# 120
# 30
# 237
# 73
# 10

# %%
def featureExtractor(img):
    img = img[0:94,0:94]
    ret, th = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU) 
    th = th/255
    skeleton = skimage.morphology.skeletonize(th)
    skeleton = np.uint8(skeleton)*255
    mask = img*255

    (minutiaeTerm, minutiaeBif) = getTerminationBifurcation(skeleton, mask)
    FeaturesTerm, FeaturesBif = extractMinutiaeFeatures(skeleton, minutiaeTerm, minutiaeBif)
    BifLabel = skimage.measure.label(minutiaeBif, connectivity=1)  >= 1
    BifLabel = BifLabel.astype(int)
    TermLabel = skimage.measure.label(minutiaeTerm, connectivity=1)  >= 1
    TermLabel = TermLabel.astype(int)
    
    return BifLabel, TermLabel

# %%
img = cv2.imread(list_dirs[0], 0)
BifLabel, TermLabel = featureExtractor(img)

# %%
TermLabel.max()
# Out:
# 1
